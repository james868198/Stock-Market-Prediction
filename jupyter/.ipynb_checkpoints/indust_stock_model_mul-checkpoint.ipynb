# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.utils import normalize
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
apple = pd.read_csv('../data/transactions/Tech/AAPL.csv')  
google = pd.read_csv('../data/transactions/Tech/GOOG.csv')  
fb = pd.read_csv('../data/transactions/Tech/FB.csv')  
microsoft = pd.read_csv('../data/transactions/Tech/MSFT.csv')  
amazon = pd.read_csv('../data/transactions/Tech/AMZN.csv')  
# print(apple)

# %%
def normalization(data):
    scl = MinMaxScaler()
    return scl.fit_transform(data)
def deDormalization(arr,mean,ma,mi):
    return (arr*(ma-mi)+ mean)
def getStock(stock):
    
    date = pd.to_datetime(stock["Date"])
    
    year = np.array(date.dt.year)/3000
    year = year.reshape(year.shape[0],1)
    month = np.array(date.dt.month)/12
    month = month.reshape(month.shape[0],1)
    day = np.array(date.dt.day)/30
    day = day.reshape(day.shape[0],1)
   
    openData = np.array(stock['Open'])
    openData = normalization(openData)
    openData = openData.reshape(openData.shape[0],1)
    High = np.array(stock['High'])
    High = normalization(High)
    High = High.reshape(High.shape[0],1)
    Low = np.array(stock['Low'])
    Low = normalization(Low)
    Low = Low.reshape(Low.shape[0],1)
    volume = np.array(stock['Volume'])
    volume = normalization(volume)
    volume = volume.reshape(volume.shape[0],1)
    
    output = np.concatenate((year,month,day,openData,High,Low,volume), axis=1)
    CloseData = np.array(stock['Close'])
    
    return output, CloseData

def processData(data,result,input_unit,output_unit):
    X,Y = [],[]
    for i in range(len(data)-input_unit-output_unit):
        X.append(data[i:(i+input_unit)])
        temp = [result[j+i+input_unit] for j in range(output_unit)]
        Y.append(temp)
    return np.array(X),np.array(Y)

# %%
#model parameters
cell_unit = 128
learn_rate = 1e-2
decay_rate = 1e-6
train_epochs = 300

#input parameters
intput = apple
time_num = 2
output_num = 2
precentage = 0.75

# %%
mean =  np.mean(intput)
ma =  np.max(intput)
mi =  np.min(intput)
data,result = getStock(intput)
print(data[10])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-2853286ee95d> in <module>
#       3 ma =  np.max(intput)
#       4 mi =  np.min(intput)
# ----> 5 data,result = getStock(intput)
#       6 # data = normalization(data)
#       7 print(data[10])
#
# <ipython-input-2-49a7c2df68a9> in getStock(stock)
#      17
#      18     openData = np.array(stock['Open'])
# ---> 19     openData = normalization(openData)
#      20     openData = openData.reshape(openData.shape[0],1)
#      21     High = np.array(stock['High'])
#
# <ipython-input-2-49a7c2df68a9> in normalization(data)
#       2 def normalization(data):
#       3     scl = MinMaxScaler()
# ----> 4     return scl.fit_transform(data)
#       5 def deDormalization(arr,mean,ma,mi):
#       6     return (arr*(ma-mi)+ mean)
#
# ~/anaconda3/envs/stock-pred/lib/python3.6/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     462         if y is None:
#     463             # fit method of arity 1 (unsupervised transformation)
# --> 464             return self.fit(X, **fit_params).transform(X)
#     465         else:
#     466             # fit method of arity 2 (supervised transformation)
#
# ~/anaconda3/envs/stock-pred/lib/python3.6/site-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#     332         # Reset internal state before fitting
#     333         self._reset()
# --> 334         return self.partial_fit(X, y)
#     335
#     336     def partial_fit(self, X, y=None):
#
# ~/anaconda3/envs/stock-pred/lib/python3.6/site-packages/sklearn/preprocessing/data.py in partial_fit(self, X, y)
#     360         X = check_array(X, copy=self.copy, warn_on_dtype=True,
#     361                         estimator=self, dtype=FLOAT_DTYPES,
# --> 362                         force_all_finite="allow-nan")
#     363
#     364         data_min = np.nanmin(X, axis=0)
#
# ~/anaconda3/envs/stock-pred/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     550                     "Reshape your data either using array.reshape(-1, 1) if "
#     551                     "your data has a single feature or array.reshape(1, -1) "
# --> 552                     "if it contains a single sample.".format(array))
#     553
#     554         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 79.382858  78.980003  76.778572 ... 155.839996 157.5      158.529999].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
data,result = processData(data,result,time_num,output_num)
samples_num = data.shape[1]
features_num = data.shape[2]
print(data.shape)
print(result.shape)
n = len(data)
train_size = int(n*precentage)
data_train,data_test = data[0:train_size],data[train_size:]
result_train,result_test = result[0:train_size],result[train_size:]
print(data_train.shape)
print(result_train.shape)

# %%
# print(data_train)
print(result_train)
# Out:
# [[ 77.704285  77.148575]
#  [ 77.148575  77.637146]
#  [ 77.637146  76.645714]
#  ...
#  [150.550003 153.139999]
#  [153.139999 154.229996]
#  [154.229996 153.279999]]

# %%
# basic model

model = Sequential() # most common
model.add(LSTM(cell_unit, input_shape = (time_num,features_num), activation = 'relu')) 
# model.add(Dropout(0.2))

# model.add(LSTM(cell_unit, activation = 'relu'))
# model.add(Dropout(0.2))

# model.add(Dense(time_steps, activation = 'relu'))
# model.add(Dropout(0.2))

model.add(Dense(1))

apt = tf.keras.optimizers.Adam(lr=learn_rate, decay=decay_rate)
model.compile(optimizer=apt, loss='mse') 
callback = EarlyStopping(monitor='val_loss', patience=10,verbose=1,mode='auto')

# %%
# basic model mul output

model = Sequential() # most common
model.add(LSTM(cell_unit, input_shape = (time_num,features_num), activation = 'relu')) 
# model.add(Dropout(0.2))

# model.add(LSTM(cell_unit, activation = 'relu'))
# model.add(Dropout(0.2))

# model.add(Dense(time_steps, activation = 'relu'))
# model.add(Dropout(0.2))

model.add(Dense(output_num))

apt = tf.keras.optimizers.Adam(lr=learn_rate, decay=decay_rate)
model.compile(optimizer=apt, loss='mse') 
callback = EarlyStopping(monitor='val_loss', patience=10,verbose=1,mode='auto')

# %%
# mul model 1

model = Sequential() # most common
model.add(LSTM(cell_unit, input_shape = (time_num,features_num),return_sequences = True, activation = 'relu')) 
model.add(Dropout(0.2))
model.add(LSTM(cell_unit, activation = 'relu',return_sequences = True))
model.add(Dropout(0.2))
model.add(Dense(time_num, activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(output_num))

apt = tf.keras.optimizers.Adam(lr=learn_rate, decay=decay_rate)
model.compile(optimizer=apt, loss='mse') 
callback = EarlyStopping(monitor='val_loss', patience=10,verbose=1,mode='auto')

# %%
# model 1

model = Sequential() # most common
model.add(LSTM(cell_unit, input_shape = (time_num,features_num), activation = 'relu')) 
model.add(Dropout(0.2))
model.add(Dense(1))

apt = tf.keras.optimizers.Adam(lr=learn_rate, decay=decay_rate)
model.compile(optimizer=apt, loss='mse') 
callback = EarlyStopping(monitor='loss', patience=10,verbose=1,mode='auto')

# %%
history = model.fit(data_train,result_train, epochs = train_epochs, validation_data=(data_test,result_test),shuffle=False,callbacks =[callback])
# Out:
# Train on 940 samples, validate on 314 samples
# Epoch 1/300
# 940/940 [==============================] - 2s 3ms/step - loss: 7804.2294 - val_loss: 7648.2060
# Epoch 2/300
# 940/940 [==============================] - 0s 232us/step - loss: 4980.3295 - val_loss: 12893.9132
# Epoch 3/300
# 940/940 [==============================] - 0s 224us/step - loss: 931.1767 - val_loss: 6199.8001
# Epoch 4/300
# 940/940 [==============================] - 0s 227us/step - loss: 787.6051 - val_loss: 2818.8020
# Epoch 5/300
# 940/940 [==============================] - 0s 231us/step - loss: 531.5725 - val_loss: 643.1489
# Epoch 6/300
# 940/940 [==============================] - 0s 241us/step - loss: 297.4922 - val_loss: 392.1717
# Epoch 7/300
# 940/940 [==============================] - 0s 230us/step - loss: 179.3346 - val_loss: 394.7947
# Epoch 8/300
# 940/940 [==============================] - 0s 246us/step - loss: 152.8885 - val_loss: 242.6765
# Epoch 9/300
# 940/940 [==============================] - 0s 230us/step - loss: 121.4348 - val_loss: 151.2639
# Epoch 10/300
# 940/940 [==============================] - 0s 241us/step - loss: 86.0537 - val_loss: 113.7460
# Epoch 11/300
# 940/940 [==============================] - 0s 240us/step - loss: 58.3923 - val_loss: 102.5883
# Epoch 12/300
# 940/940 [==============================] - 0s 243us/step - loss: 39.4433 - val_loss: 100.5440
# Epoch 13/300
# 940/940 [==============================] - 0s 264us/step - loss: 27.4320 - val_loss: 99.5894
# Epoch 14/300
# 940/940 [==============================] - 0s 266us/step - loss: 19.6357 - val_loss: 99.4420
# Epoch 15/300
# 940/940 [==============================] - 0s 270us/step - loss: 15.1495 - val_loss: 97.8611
# Epoch 16/300
# 940/940 [==============================] - 0s 284us/step - loss: 12.7722 - val_loss: 94.2220
# Epoch 17/300
# 940/940 [==============================] - 0s 438us/step - loss: 11.3013 - val_loss: 89.8335
# Epoch 18/300
# 940/940 [==============================] - 0s 228us/step - loss: 10.3122 - val_loss: 86.7626
# Epoch 19/300
# 940/940 [==============================] - 0s 224us/step - loss: 9.6935 - val_loss: 82.5390
# Epoch 20/300
# 940/940 [==============================] - 0s 227us/step - loss: 9.1848 - val_loss: 79.5739
# Epoch 21/300
# 940/940 [==============================] - 0s 235us/step - loss: 8.9610 - val_loss: 75.8160
# Epoch 22/300
# 940/940 [==============================] - 0s 238us/step - loss: 8.6360 - val_loss: 73.1675
# Epoch 23/300
# 940/940 [==============================] - 0s 215us/step - loss: 8.5966 - val_loss: 69.9376
# Epoch 24/300
# 940/940 [==============================] - 0s 248us/step - loss: 6.8854 - val_loss: 28.1091
# Epoch 53/300
# 940/940 [==============================] - 0s 237us/step - loss: 6.8906 - val_loss: 27.8655
# Epoch 54/300
# 940/940 [==============================] - 0s 207us/step - loss: 6.8313 - val_loss: 27.5304
# Epoch 55/300
# 940/940 [==============================] - 0s 205us/step - loss: 6.8313 - val_loss: 27.3560
# Epoch 56/300
# 940/940 [==============================] - 0s 201us/step - loss: 6.7821 - val_loss: 27.1162
# Epoch 57/300
# 940/940 [==============================] - 0s 202us/step - loss: 6.7845 - val_loss: 27.0202
# Epoch 58/300
# 940/940 [==============================] - 0s 205us/step - loss: 6.8070 - val_loss: 27.0464
# Epoch 59/300
# 940/940 [==============================] - 0s 202us/step - loss: 6.9185 - val_loss: 27.2010
# Epoch 60/300
# 940/940 [==============================] - 0s 207us/step - loss: 7.1714 - val_loss: 27.4824
# Epoch 61/300
# 940/940 [==============================] - 0s 201us/step - loss: 7.5123 - val_loss: 27.9777
# Epoch 62/300
# 940/940 [==============================] - 0s 200us/step - loss: 7.8272 - val_loss: 28.2455
# Epoch 63/300
# 940/940 [==============================] - 0s 208us/step - loss: 7.6635 - val_loss: 27.9535
# Epoch 64/300
# 940/940 [==============================] - 0s 203us/step - loss: 7.0569 - val_loss: 26.9158
# Epoch 65/300
# 940/940 [==============================] - 0s 212us/step - loss: 6.5740 - val_loss: 25.4948
# Epoch 66/300
# 940/940 [==============================] - 0s 209us/step - loss: 7.5202 - val_loss: 25.0157
# Epoch 67/300
# 940/940 [==============================] - 0s 228us/step - loss: 12.2610 - val_loss: 27.4509
# Epoch 68/300
# 940/940 [==============================] - 0s 193us/step - loss: 22.0074 - val_loss: 30.7956
# Epoch 69/300
# 940/940 [==============================] - 0s 205us/step - loss: 30.5596 - val_loss: 32.2600
# Epoch 70/300
# 940/940 [==============================] - 0s 192us/step - loss: 25.1663 - val_loss: 28.7727
# Epoch 71/300
# 940/940 [==============================] - 0s 203us/step - loss: 12.7359 - val_loss: 29.2618
# Epoch 72/300
# 940/940 [==============================] - 0s 207us/step - loss: 40.9726 - val_loss: 49.4532
# Epoch 73/300
# 940/940 [==============================] - 0s 206us/step - loss: 146.8228 - val_loss: 77.1595
# Epoch 74/300
# 940/940 [==============================] - 0s 205us/step - loss: 116.7499 - val_loss: 69.9536
# Epoch 75/300
# 940/940 [==============================] - 0s 204us/step - loss: 97.3038 - val_loss: 67.5369
# Epoch 76/300
# 940/940 [==============================] - 0s 198us/step - loss: 331.8010 - val_loss: 311.3759
# Epoch 00076: early stopping

# %%
predictions = model.predict([data_test])
predictions = np.array(predictions)
real = result_test

# %%
plt.plot(predictions,color='green')
plt.plot(real,color='red')
plt.ylabel("price")
plt.xlabel("time")

plt.show()

# %%
# error
plt.plot((predictions-real)/(max(real)-min(real)),color='black')
plt.ylabel("error")
plt.xlabel("time")

plt.show()
print(real)
